# %%
import pandas as pd
from sklearn.metrics import classification_report,roc_auc_score, confusion_matrix, roc_curve
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense, Concatenate
from tensorflow.keras.models import Model

def set_seed(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    random.seed(seed)

set_seed(42)
results={}
scale=StandardScaler()
# Out:
# 2026-05-28 17:34:10.904711: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#import dataframe
df_modelling=pd.read_parquet("../df_modelling.parquet")

# %% [markdown]
# Without Rolling Window:

# %%
#creating market vector
# 'Stock_Date', 'Closing Price($)', 'relative difference',
#        'comment_published_at_median_YMD', 'number_of_comments_at_date',
#        'comment_likes_agg', 'comment_embeddings_agg', 'comment_sentiment_agg',
#        'sentiment_tensor', 'videos_text_embeddings', 'TargetVariable:Up/Down'
numerical_columns=['Closing Price($) lag1',
'relative difference lag1',
         'number_of_comments_at_date',
    'comment_likes_agg',
    'comment_sentiment_agg',
     'sentiment_tensor']

print(df_modelling.columns)


#concating the embeddings separately
df_modelling['embeddings_vector']=df_modelling.apply(lambda row: np.concatenate((row['comment_embeddings_agg'], row['videos_text_embeddings'])), axis=1)
# Out:
# Index(['Stock_Date', 'Closing Price($)', 'relative difference',
#        'comment_published_at_YMD', 'number_of_comments_at_date',
#        'comment_likes_agg', 'comment_embeddings_agg', 'comment_sentiment_agg',
#        'sentiment_tensor', 'videos_text_embeddings', 'Difference',
#        'videos_text_embeddings_window', 'TargetVariable:Up/Down',
#        'Closing Price($) lag1', 'relative difference lag1',
#        'Calendar_Diff_Days'],
#       dtype='object')

# %%
#function for creating sequences
def create_sequences(embeddings, numeric, target, sequence_length):
    X_emb_seq = []
    X_num_seq = []
    y_seq = []

    for i in range(sequence_length, len(embeddings)):
        X_emb_seq.append(embeddings[i-sequence_length:i])
        X_num_seq.append(numeric[i-sequence_length:i])
        y_seq.append(target[i])

    return (
        np.array(X_emb_seq),
        np.array(X_num_seq),
        np.array(y_seq)
    )

# %%
# embeddings_array=np.stack(df_modelling['embeddings_vector'])
# Embeddings_reduced=embeddings_array 
# numerical_values=np.stack(df_modelling[numerical_columns].values)
# y = df_modelling['TargetVariable:Up/Down'].values

sequence_length = 20  # timesteps

#splitting data
embeddings_array = np.stack(df_modelling['embeddings_vector'])
numerical_values = np.stack(df_modelling[numerical_columns].values)
y = df_modelling['TargetVariable:Up/Down'].values


N = len(embeddings_array)
#train 70% val 20% test 10%
train_end = int(N * 0.7)
val_end = int(N * 0.9)

# Raw splits
# TRAIN
emb_train_raw = embeddings_array[:train_end]
num_train_raw = numerical_values[:train_end]
y_train_raw   = y[:train_end]

# VALIDATION
emb_val_raw = embeddings_array[train_end-sequence_length:val_end]
num_val_raw = numerical_values[train_end-sequence_length:val_end]
y_val_raw   = y[train_end-sequence_length:val_end]

# TEST
emb_test_raw = embeddings_array[val_end-sequence_length:]
num_test_raw = numerical_values[val_end-sequence_length:]
y_test_raw   = y[val_end-sequence_length:]


num_train_raw = scale.fit_transform(num_train_raw)
num_val_raw = scale.transform(num_val_raw)
num_test_raw = scale.transform(num_test_raw)

# %%
#LSTM will look 20 steps in the past
X_emb_train, X_num_train, y_train = create_sequences(emb_train_raw, num_train_raw, y_train_raw, sequence_length)
X_emb_val, X_num_val, y_val = create_sequences(emb_val_raw, num_val_raw, y_val_raw, sequence_length)
X_emb_test, X_num_test, y_test = create_sequences(emb_test_raw, num_test_raw, y_test_raw, sequence_length)

# %%
# Inputs
embedding_input = Input(shape=(sequence_length,X_emb_train.shape[2]))   # change 50 to your seq_len
numeric_input = Input(shape=(sequence_length,X_num_train.shape[2]))

# Embeddings branch
x = LSTM(64, return_sequences=True)(embedding_input)
x = LSTM(32)(x)

#numerical branch
z= LSTM(16, return_sequences=True)(numeric_input)
z= LSTM(8)(z)

# Concatenate numeric features
x = Concatenate()([x, z])

# Output
output = Dense(1, activation='sigmoid')(x)

# Build model
model = Model(inputs=[embedding_input, numeric_input], outputs=output)

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 20, 512)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 20, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 20, 64)    │    147,712 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 20, 16)    │      1,472 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ (None, 32)        │     12,416 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ (None, 8)         │        800 │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 40)        │          0 │ lstm_1[0][0],     │
# │ (Concatenate)       │                   │            │ lstm_3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1)         │         41 │ concatenate[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 162,441 (634.54 KB)
#  Trainable params: 162,441 (634.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    [X_emb_train, X_num_train],  # inputs
    y_train,                        # labels
    validation_data=([X_emb_val, X_num_val], y_val),
    epochs=200,                      # start with 10, can increase
    batch_size=32,                  # tune depending on memory
    shuffle=False
)
# Out:
# Epoch 1/200
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor', 'keras_tensor_1']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - accuracy: 0.4335 - loss: 0.7039 - val_accuracy: 0.5306 - val_loss: 0.6860
# Epoch 2/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4557 - loss: 0.6962 - val_accuracy: 0.5816 - val_loss: 0.6896
# Epoch 3/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4903 - loss: 0.6954 - val_accuracy: 0.4796 - val_loss: 0.6925
# Epoch 4/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4903 - loss: 0.6930 - val_accuracy: 0.5204 - val_loss: 0.6930
# Epoch 5/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5283 - loss: 0.6891 - val_accuracy: 0.5102 - val_loss: 0.6929
# Epoch 6/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5735 - loss: 0.6844 - val_accuracy: 0.5204 - val_loss: 0.6937
# Epoch 7/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5743 - loss: 0.6779 - val_accuracy: 0.5000 - val_loss: 0.6951
# Epoch 8/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5878 - loss: 0.6663 - val_accuracy: 0.4286 - val_loss: 0.7150
# Epoch 9/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5942 - loss: 0.6613 - val_accuracy: 0.5306 - val_loss: 0.7664
# Epoch 10/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5847 - loss: 0.6900 - val_accuracy: 0.4898 - val_loss: 0.7138
# Epoch 11/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5617 - loss: 0.6826 - val_accuracy: 0.5204 - val_loss: 0.7012
# Epoch 12/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6249 - loss: 0.6663 - val_accuracy: 0.4286 - val_loss: 0.7076
# Epoch 13/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6026 - loss: 0.6511 - val_accuracy: 0.4184 - val_loss: 0.7493
# Epoch 14/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5799 - loss: 0.6663 - val_accuracy: 0.4082 - val_loss: 0.7253
# Epoch 15/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6357 - loss: 0.6536 - val_accuracy: 0.4184 - val_loss: 0.7286
# Epoch 16/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6021 - loss: 0.6339 - val_accuracy: 0.3980 - val_loss: 0.7702
# Epoch 17/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6232 - loss: 0.6292 - val_accuracy: 0.4694 - val_loss: 0.7883
# Epoch 18/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6456 - loss: 0.6269 - val_accuracy: 0.4490 - val_loss: 0.8065
# Epoch 19/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6183 - loss: 0.6435 - val_accuracy: 0.4490 - val_loss: 0.7401
# Epoch 20/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6457 - loss: 0.6357 - val_accuracy: 0.4592 - val_loss: 0.8038
# Epoch 21/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6498 - loss: 0.6087 - val_accuracy: 0.4184 - val_loss: 0.8384
# Epoch 22/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6549 - loss: 0.5894 - val_accuracy: 0.4286 - val_loss: 0.8143
# Epoch 23/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6709 - loss: 0.5839 - val_accuracy: 0.4796 - val_loss: 0.8848
# Epoch 24/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6666 - loss: 0.5848 - val_accuracy: 0.3980 - val_loss: 0.9896
# Epoch 25/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6812 - loss: 0.6268 - val_accuracy: 0.4490 - val_loss: 0.7470
# Epoch 26/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6557 - loss: 0.6020 - val_accuracy: 0.4184 - val_loss: 0.7728
# Epoch 27/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6609 - loss: 0.5863 - val_accuracy: 0.4490 - val_loss: 1.0907
# Epoch 28/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6806 - loss: 0.6420 - val_accuracy: 0.5000 - val_loss: 0.8596
# Epoch 29/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6084 - loss: 0.6404 - val_accuracy: 0.4388 - val_loss: 0.7739
# Epoch 30/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6257 - loss: 0.6422 - val_accuracy: 0.5204 - val_loss: 0.7575
# Epoch 31/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6581 - loss: 0.6110 - val_accuracy: 0.5000 - val_loss: 0.7497
# Epoch 32/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6478 - loss: 0.6201 - val_accuracy: 0.4286 - val_loss: 0.8109
# Epoch 33/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6890 - loss: 0.5620 - val_accuracy: 0.4592 - val_loss: 0.9138
# Epoch 34/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6861 - loss: 0.5516 - val_accuracy: 0.4796 - val_loss: 0.8484
# Epoch 35/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7006 - loss: 0.5670 - val_accuracy: 0.4898 - val_loss: 0.8060
# Epoch 36/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6771 - loss: 0.5915 - val_accuracy: 0.3980 - val_loss: 1.0578
# Epoch 37/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7404 - loss: 0.5494 - val_accuracy: 0.4184 - val_loss: 0.9676
# Epoch 38/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6636 - loss: 0.5772 - val_accuracy: 0.4898 - val_loss: 0.7655
# Epoch 39/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6743 - loss: 0.5780 - val_accuracy: 0.4694 - val_loss: 0.7736
# Epoch 40/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7354 - loss: 0.5416 - val_accuracy: 0.4184 - val_loss: 1.0301
# Epoch 41/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7121 - loss: 0.5288 - val_accuracy: 0.4388 - val_loss: 1.0414
# Epoch 42/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6878 - loss: 0.5495 - val_accuracy: 0.4694 - val_loss: 0.8471
# Epoch 43/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7161 - loss: 0.5536 - val_accuracy: 0.4490 - val_loss: 0.9213
# Epoch 44/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7272 - loss: 0.5179 - val_accuracy: 0.4592 - val_loss: 1.0824
# Epoch 45/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7483 - loss: 0.4946 - val_accuracy: 0.4286 - val_loss: 1.0579
# Epoch 46/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7128 - loss: 0.5097 - val_accuracy: 0.4898 - val_loss: 0.8921
# Epoch 47/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7705 - loss: 0.4946 - val_accuracy: 0.4592 - val_loss: 0.9673
# Epoch 48/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7368 - loss: 0.5017 - val_accuracy: 0.5102 - val_loss: 1.1035
# Epoch 49/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7876 - loss: 0.4699 - val_accuracy: 0.4796 - val_loss: 1.2507
# Epoch 50/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7335 - loss: 0.5619 - val_accuracy: 0.4694 - val_loss: 0.8095
# Epoch 51/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6637 - loss: 0.5919 - val_accuracy: 0.4184 - val_loss: 1.0434
# Epoch 52/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7174 - loss: 0.5562 - val_accuracy: 0.5000 - val_loss: 0.8327
# Epoch 53/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7276 - loss: 0.5418 - val_accuracy: 0.4490 - val_loss: 0.7996
# Epoch 54/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7118 - loss: 0.5575 - val_accuracy: 0.4592 - val_loss: 0.8068
# Epoch 55/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7445 - loss: 0.5042 - val_accuracy: 0.4184 - val_loss: 1.1258
# Epoch 56/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7582 - loss: 0.4803 - val_accuracy: 0.4592 - val_loss: 1.5234
# Epoch 57/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7514 - loss: 0.5668 - val_accuracy: 0.4694 - val_loss: 0.9278
# Epoch 58/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7430 - loss: 0.5050 - val_accuracy: 0.4490 - val_loss: 0.8818
# Epoch 59/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7606 - loss: 0.4891 - val_accuracy: 0.4592 - val_loss: 1.1372
# Epoch 60/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7768 - loss: 0.4521 - val_accuracy: 0.4592 - val_loss: 1.1532
# Epoch 61/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7981 - loss: 0.4352 - val_accuracy: 0.4592 - val_loss: 1.2355
# Epoch 62/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8000 - loss: 0.4208 - val_accuracy: 0.4898 - val_loss: 1.1839
# Epoch 63/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7923 - loss: 0.4237 - val_accuracy: 0.4898 - val_loss: 1.3494
# Epoch 64/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7987 - loss: 0.4203 - val_accuracy: 0.4082 - val_loss: 1.6513
# Epoch 65/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7512 - loss: 0.5098 - val_accuracy: 0.4796 - val_loss: 0.9143
# Epoch 66/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7524 - loss: 0.5035 - val_accuracy: 0.5000 - val_loss: 0.8864
# Epoch 67/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7681 - loss: 0.4673 - val_accuracy: 0.4490 - val_loss: 1.2254
# Epoch 68/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7826 - loss: 0.4234 - val_accuracy: 0.4796 - val_loss: 1.2283
# Epoch 69/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8083 - loss: 0.4004 - val_accuracy: 0.4694 - val_loss: 1.4159
# Epoch 70/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8148 - loss: 0.3785 - val_accuracy: 0.4592 - val_loss: 1.5358
# Epoch 71/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8256 - loss: 0.3730 - val_accuracy: 0.4388 - val_loss: 1.9352
# Epoch 72/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8390 - loss: 0.4007 - val_accuracy: 0.4490 - val_loss: 1.6868
# Epoch 73/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8384 - loss: 0.3583 - val_accuracy: 0.4694 - val_loss: 1.5235
# Epoch 74/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8030 - loss: 0.4390 - val_accuracy: 0.4592 - val_loss: 1.0238
# Epoch 75/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6856 - loss: 0.5770 - val_accuracy: 0.4796 - val_loss: 0.9805
# Epoch 76/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6154 - loss: 0.6418 - val_accuracy: 0.4796 - val_loss: 0.9786
# Epoch 77/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7630 - loss: 0.4921 - val_accuracy: 0.4592 - val_loss: 1.2051
# Epoch 78/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8106 - loss: 0.4307 - val_accuracy: 0.4694 - val_loss: 1.4008
# Epoch 79/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8164 - loss: 0.4049 - val_accuracy: 0.4388 - val_loss: 1.3380
# Epoch 80/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7247 - loss: 0.4877 - val_accuracy: 0.4796 - val_loss: 1.0450
# Epoch 81/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7833 - loss: 0.4169 - val_accuracy: 0.4694 - val_loss: 1.7108
# Epoch 82/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8224 - loss: 0.4064 - val_accuracy: 0.4796 - val_loss: 1.2916
# Epoch 83/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7534 - loss: 0.4346 - val_accuracy: 0.4898 - val_loss: 1.0802
# Epoch 84/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8459 - loss: 0.4086 - val_accuracy: 0.4490 - val_loss: 1.6593
# Epoch 85/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8477 - loss: 0.3530 - val_accuracy: 0.4796 - val_loss: 1.4461
# Epoch 86/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8603 - loss: 0.3347 - val_accuracy: 0.4592 - val_loss: 1.9869
# Epoch 87/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8539 - loss: 0.3291 - val_accuracy: 0.4796 - val_loss: 1.6599
# Epoch 88/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8882 - loss: 0.2949 - val_accuracy: 0.4490 - val_loss: 1.9875
# Epoch 89/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8171 - loss: 0.3492 - val_accuracy: 0.4388 - val_loss: 1.7645
# Epoch 90/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8462 - loss: 0.3499 - val_accuracy: 0.4796 - val_loss: 1.2164
# Epoch 91/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7530 - loss: 0.4461 - val_accuracy: 0.4592 - val_loss: 0.9634
# Epoch 92/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7593 - loss: 0.4560 - val_accuracy: 0.4388 - val_loss: 1.7956
# Epoch 93/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8441 - loss: 0.3616 - val_accuracy: 0.4286 - val_loss: 1.5627
# Epoch 94/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8494 - loss: 0.3249 - val_accuracy: 0.4388 - val_loss: 2.0136
# Epoch 95/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8353 - loss: 0.3233 - val_accuracy: 0.4592 - val_loss: 1.5789
# Epoch 96/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8620 - loss: 0.3282 - val_accuracy: 0.4694 - val_loss: 1.7966
# Epoch 97/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8418 - loss: 0.3211 - val_accuracy: 0.4490 - val_loss: 1.2839
# Epoch 98/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8356 - loss: 0.3669 - val_accuracy: 0.4184 - val_loss: 2.1795
# Epoch 99/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7622 - loss: 0.4838 - val_accuracy: 0.4694 - val_loss: 1.3922
# Epoch 100/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8061 - loss: 0.3973 - val_accuracy: 0.4796 - val_loss: 1.3215
# Epoch 101/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7964 - loss: 0.4158 - val_accuracy: 0.4592 - val_loss: 1.4292
# Epoch 102/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8618 - loss: 0.3262 - val_accuracy: 0.4490 - val_loss: 2.1062
# Epoch 103/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8779 - loss: 0.2885 - val_accuracy: 0.4490 - val_loss: 1.7353
# Epoch 104/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8537 - loss: 0.3011 - val_accuracy: 0.4490 - val_loss: 1.9657
# Epoch 105/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8203 - loss: 0.3429 - val_accuracy: 0.4388 - val_loss: 0.9325
# Epoch 106/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7396 - loss: 0.4955 - val_accuracy: 0.4490 - val_loss: 1.2832
# Epoch 107/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8395 - loss: 0.3793 - val_accuracy: 0.4184 - val_loss: 1.8304
# Epoch 108/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8168 - loss: 0.3851 - val_accuracy: 0.4592 - val_loss: 1.6053
# Epoch 109/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8619 - loss: 0.3081 - val_accuracy: 0.4490 - val_loss: 1.6998
# Epoch 110/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8907 - loss: 0.2734 - val_accuracy: 0.4490 - val_loss: 1.9366
# Epoch 111/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9055 - loss: 0.2750 - val_accuracy: 0.4490 - val_loss: 1.9251
# Epoch 112/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8252 - loss: 0.3527 - val_accuracy: 0.4592 - val_loss: 1.7560
# Epoch 113/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8290 - loss: 0.3458 - val_accuracy: 0.4490 - val_loss: 1.6102
# Epoch 114/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7940 - loss: 0.4035 - val_accuracy: 0.4490 - val_loss: 1.4844
# Epoch 115/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8843 - loss: 0.3015 - val_accuracy: 0.4592 - val_loss: 1.9800
# Epoch 116/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8811 - loss: 0.2770 - val_accuracy: 0.4592 - val_loss: 1.8185
# Epoch 117/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8592 - loss: 0.2671 - val_accuracy: 0.4286 - val_loss: 2.0997
# Epoch 118/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9176 - loss: 0.2373 - val_accuracy: 0.4184 - val_loss: 2.3251
# Epoch 119/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9031 - loss: 0.2361 - val_accuracy: 0.4082 - val_loss: 2.0012
# Epoch 120/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9432 - loss: 0.2144 - val_accuracy: 0.4082 - val_loss: 2.4865
# Epoch 121/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8987 - loss: 0.2459 - val_accuracy: 0.4082 - val_loss: 1.8068
# Epoch 122/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8345 - loss: 0.3280 - val_accuracy: 0.4694 - val_loss: 1.1859
# Epoch 123/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7530 - loss: 0.4703 - val_accuracy: 0.4490 - val_loss: 1.8520
# Epoch 124/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7250 - loss: 0.4845 - val_accuracy: 0.4388 - val_loss: 0.8555
# Epoch 125/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7275 - loss: 0.5121 - val_accuracy: 0.4490 - val_loss: 0.8374
# Epoch 126/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7606 - loss: 0.4870 - val_accuracy: 0.4490 - val_loss: 0.9597
# Epoch 127/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8059 - loss: 0.4442 - val_accuracy: 0.4082 - val_loss: 1.2644
# Epoch 128/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8351 - loss: 0.4054 - val_accuracy: 0.4184 - val_loss: 1.9600
# Epoch 129/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7555 - loss: 0.5016 - val_accuracy: 0.4694 - val_loss: 1.5199
# Epoch 130/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7949 - loss: 0.4486 - val_accuracy: 0.4592 - val_loss: 1.4566
# Epoch 131/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8541 - loss: 0.3976 - val_accuracy: 0.4694 - val_loss: 1.3940
# Epoch 132/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8248 - loss: 0.3317 - val_accuracy: 0.4184 - val_loss: 1.9320
# Epoch 133/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8859 - loss: 0.2746 - val_accuracy: 0.4184 - val_loss: 2.1931
# Epoch 134/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9287 - loss: 0.2269 - val_accuracy: 0.4592 - val_loss: 2.2285
# Epoch 135/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9339 - loss: 0.2106 - val_accuracy: 0.4286 - val_loss: 2.2857
# Epoch 136/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9160 - loss: 0.2158 - val_accuracy: 0.4388 - val_loss: 2.1352
# Epoch 137/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9103 - loss: 0.2248 - val_accuracy: 0.4082 - val_loss: 2.2983
# Epoch 138/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9281 - loss: 0.2163 - val_accuracy: 0.4184 - val_loss: 2.4646
# Epoch 139/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8147 - loss: 0.3928 - val_accuracy: 0.4388 - val_loss: 1.6916
# Epoch 140/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8012 - loss: 0.3954 - val_accuracy: 0.4796 - val_loss: 1.5165
# Epoch 141/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8380 - loss: 0.3722 - val_accuracy: 0.4592 - val_loss: 1.3471
# Epoch 142/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8653 - loss: 0.3122 - val_accuracy: 0.4490 - val_loss: 1.9464
# Epoch 143/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8870 - loss: 0.2574 - val_accuracy: 0.3980 - val_loss: 2.0486
# Epoch 144/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9014 - loss: 0.2331 - val_accuracy: 0.4082 - val_loss: 2.3927
# Epoch 145/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9408 - loss: 0.2056 - val_accuracy: 0.3980 - val_loss: 2.7828
# Epoch 146/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8850 - loss: 0.3028 - val_accuracy: 0.4286 - val_loss: 2.2354
# Epoch 147/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9271 - loss: 0.2062 - val_accuracy: 0.3980 - val_loss: 2.5192
# Epoch 148/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9269 - loss: 0.2011 - val_accuracy: 0.4184 - val_loss: 2.5082
# Epoch 149/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8821 - loss: 0.2446 - val_accuracy: 0.3878 - val_loss: 2.2506
# Epoch 150/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8458 - loss: 0.3319 - val_accuracy: 0.4592 - val_loss: 1.1011
# Epoch 151/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7561 - loss: 0.5045 - val_accuracy: 0.4286 - val_loss: 1.3938
# Epoch 152/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8686 - loss: 0.3080 - val_accuracy: 0.3980 - val_loss: 2.2152
# Epoch 153/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8491 - loss: 0.3520 - val_accuracy: 0.4286 - val_loss: 1.9420
# Epoch 154/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9336 - loss: 0.2335 - val_accuracy: 0.4286 - val_loss: 2.2092
# Epoch 155/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9127 - loss: 0.2533 - val_accuracy: 0.4286 - val_loss: 2.4163
# Epoch 156/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8993 - loss: 0.2219 - val_accuracy: 0.4388 - val_loss: 2.3025
# Epoch 157/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9389 - loss: 0.1829 - val_accuracy: 0.4184 - val_loss: 2.3853
# Epoch 158/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9515 - loss: 0.1729 - val_accuracy: 0.4082 - val_loss: 2.6348
# Epoch 159/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9321 - loss: 0.2090 - val_accuracy: 0.3980 - val_loss: 2.7330
# Epoch 160/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9316 - loss: 0.1727 - val_accuracy: 0.4184 - val_loss: 2.5290
# Epoch 161/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9167 - loss: 0.2088 - val_accuracy: 0.4184 - val_loss: 2.3465
# Epoch 162/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9298 - loss: 0.1939 - val_accuracy: 0.3980 - val_loss: 2.4641
# Epoch 163/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8817 - loss: 0.2658 - val_accuracy: 0.4388 - val_loss: 2.4388
# Epoch 164/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8942 - loss: 0.2733 - val_accuracy: 0.3980 - val_loss: 2.0604
# Epoch 165/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8638 - loss: 0.3028 - val_accuracy: 0.4286 - val_loss: 2.0206
# Epoch 166/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9298 - loss: 0.2153 - val_accuracy: 0.4184 - val_loss: 2.6917
# Epoch 167/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9288 - loss: 0.1876 - val_accuracy: 0.4286 - val_loss: 2.3310
# Epoch 168/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9330 - loss: 0.1686 - val_accuracy: 0.4184 - val_loss: 2.8123
# Epoch 169/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9287 - loss: 0.1756 - val_accuracy: 0.4388 - val_loss: 2.4959
# Epoch 170/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9406 - loss: 0.1552 - val_accuracy: 0.4082 - val_loss: 2.8689
# Epoch 171/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9594 - loss: 0.1431 - val_accuracy: 0.3980 - val_loss: 3.0714
# Epoch 172/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9326 - loss: 0.1488 - val_accuracy: 0.4082 - val_loss: 2.8779
# Epoch 173/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9411 - loss: 0.1748 - val_accuracy: 0.4592 - val_loss: 1.9278
# Epoch 174/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8332 - loss: 0.3161 - val_accuracy: 0.4082 - val_loss: 2.7515
# Epoch 175/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9009 - loss: 0.2087 - val_accuracy: 0.4286 - val_loss: 2.7176
# Epoch 176/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8771 - loss: 0.2895 - val_accuracy: 0.4388 - val_loss: 1.8613
# Epoch 177/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8510 - loss: 0.3275 - val_accuracy: 0.4184 - val_loss: 2.0395
# Epoch 178/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9041 - loss: 0.2139 - val_accuracy: 0.3980 - val_loss: 2.7406
# Epoch 179/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9273 - loss: 0.1720 - val_accuracy: 0.3878 - val_loss: 2.5871
# Epoch 180/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9424 - loss: 0.1526 - val_accuracy: 0.3980 - val_loss: 2.7486
# Epoch 181/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9558 - loss: 0.1394 - val_accuracy: 0.4082 - val_loss: 3.0156
# Epoch 182/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9369 - loss: 0.1434 - val_accuracy: 0.4184 - val_loss: 2.8342
# Epoch 183/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9454 - loss: 0.1542 - val_accuracy: 0.3980 - val_loss: 2.8348
# Epoch 184/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9408 - loss: 0.1400 - val_accuracy: 0.4184 - val_loss: 3.0391
# Epoch 185/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9106 - loss: 0.1866 - val_accuracy: 0.4388 - val_loss: 2.8436
# Epoch 186/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8924 - loss: 0.2917 - val_accuracy: 0.4286 - val_loss: 1.9279
# Epoch 187/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7769 - loss: 0.4376 - val_accuracy: 0.4082 - val_loss: 2.1476
# Epoch 188/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8528 - loss: 0.3070 - val_accuracy: 0.4490 - val_loss: 1.4817
# Epoch 189/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8689 - loss: 0.3091 - val_accuracy: 0.3980 - val_loss: 1.9743
# Epoch 190/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8134 - loss: 0.3610 - val_accuracy: 0.4490 - val_loss: 1.4360
# Epoch 191/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8915 - loss: 0.2977 - val_accuracy: 0.4388 - val_loss: 2.3735
# Epoch 192/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9268 - loss: 0.2066 - val_accuracy: 0.4592 - val_loss: 2.3313
# Epoch 193/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9270 - loss: 0.1929 - val_accuracy: 0.4184 - val_loss: 2.7271
# Epoch 194/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9289 - loss: 0.1833 - val_accuracy: 0.4082 - val_loss: 2.3603
# Epoch 195/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9227 - loss: 0.1958 - val_accuracy: 0.4082 - val_loss: 2.7061
# Epoch 196/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9533 - loss: 0.1424 - val_accuracy: 0.4286 - val_loss: 2.9080
# Epoch 197/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9419 - loss: 0.1447 - val_accuracy: 0.4082 - val_loss: 3.0027
# Epoch 198/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9560 - loss: 0.1201 - val_accuracy: 0.4184 - val_loss: 3.0623
# Epoch 199/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9655 - loss: 0.1179 - val_accuracy: 0.4184 - val_loss: 3.0767
# Epoch 200/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9604 - loss: 0.1137 - val_accuracy: 0.4286 - val_loss: 3.0342

# %%
thresholds=np.arange(0.0,1.01,0.1)
f1_scores=[]
best_f1=0

#selecting best threshold on val data

y_prob = model.predict([X_emb_val, X_num_val])
for threshold in thresholds:
    y_pred_tr = (y_prob > threshold).astype(int)
    report=classification_report(y_val, y_pred_tr, output_dict=True)
    f1_scores.append(report['macro avg']['f1-score'])

#deciding the best index    
f1_score=max(f1_scores)
index_tr=f1_scores.index(f1_score)
threshold=thresholds[index_tr]

#now deciding F1 on test data with the decided best threshold
y_prob = model.predict([X_emb_test, X_num_test])
y_pred_tr = (y_prob > threshold).astype(int)
report=classification_report(y_test, y_pred_tr, output_dict=True)
f1=report['macro avg']['f1-score']
print(f"Best Result is f1 {f1} at threshold {threshold}")
results["without Window"]=[f1, threshold, report]
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Best Result is f1 0.4889445139758031 at threshold 0.4
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
y_prob = model.predict([X_emb_test, X_num_test])
y_pred = (y_prob > threshold).astype(int)
print(classification_report(y_test, y_pred))

print("confusion_matrix is:")
cm=confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, 
            annot=True, 
            fmt='d', 
            cmap='Blues',
            xticklabels=["Negative", "Positive"],
            yticklabels=["Negative", "Positive"])

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#               precision    recall  f1-score   support
#
#            0       0.42      0.65      0.51        20
#            1       0.61      0.38      0.47        29
#
#     accuracy                           0.49        49
#    macro avg       0.52      0.51      0.49        49
# weighted avg       0.53      0.49      0.49        49
#
# confusion_matrix is:

# %%
auc=roc_auc_score(y_test, y_prob)

fpr, tpr, thresholds = roc_curve(y_test, y_prob)

plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # random line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.title("ROC for LSTM with 512 embeddings and 6 numerical features")
plt.show()

# %% [markdown]
# With Rolling Window

# %%
numerical_columns=['Closing Price($) lag1',
'relative difference lag1',
         'number_of_comments_at_date',
    'comment_likes_agg',
    'comment_sentiment_agg',
     'sentiment_tensor']

print(df_modelling.columns)


#concating the embeddings separately
df_modelling['embeddings_vector']=df_modelling.apply(lambda row: np.concatenate((row['comment_embeddings_agg'], row['videos_text_embeddings_window'])), axis=1)
# Out:
# Index(['Stock_Date', 'Closing Price($)', 'relative difference',
#        'comment_published_at_YMD', 'number_of_comments_at_date',
#        'comment_likes_agg', 'comment_embeddings_agg', 'comment_sentiment_agg',
#        'sentiment_tensor', 'videos_text_embeddings', 'Difference',
#        'videos_text_embeddings_window', 'TargetVariable:Up/Down',
#        'Closing Price($) lag1', 'relative difference lag1',
#        'Calendar_Diff_Days', 'embeddings_vector'],
#       dtype='object')

# %%
#function for creating sequences
def create_sequences(embeddings, numeric, target, sequence_length):
    X_emb_seq = []
    X_num_seq = []
    y_seq = []

    for i in range(sequence_length, len(embeddings)):
        X_emb_seq.append(embeddings[i-sequence_length:i])
        X_num_seq.append(numeric[i-sequence_length:i])
        y_seq.append(target[i])

    return (
        np.array(X_emb_seq),
        np.array(X_num_seq),
        np.array(y_seq)
    )

# %%
sequence_length = 20  # timesteps


#splitting data
embeddings_array = np.stack(df_modelling['embeddings_vector'])
numerical_values = np.stack(df_modelling[numerical_columns].values)
y = df_modelling['TargetVariable:Up/Down'].values


N = len(embeddings_array)
#train 70% val 20% test 10%
train_end = int(N * 0.7)
val_end = int(N * 0.9)

# TRAIN
emb_train_raw = embeddings_array[:train_end]
num_train_raw = numerical_values[:train_end]
y_train_raw   = y[:train_end]

# VALIDATION
emb_val_raw = embeddings_array[train_end-sequence_length:val_end]
num_val_raw = numerical_values[train_end-sequence_length:val_end]
y_val_raw   = y[train_end-sequence_length:val_end]

# TEST
emb_test_raw = embeddings_array[val_end-sequence_length:]
num_test_raw = numerical_values[val_end-sequence_length:]
y_test_raw   = y[val_end-sequence_length:]


num_train_raw = scale.fit_transform(num_train_raw)
num_val_raw = scale.transform(num_val_raw)
num_test_raw = scale.transform(num_test_raw)

# %%
#LSTM will look 20 steps in the past
X_emb_train, X_num_train, y_train = create_sequences(emb_train_raw, num_train_raw, y_train_raw, sequence_length)
X_emb_val, X_num_val, y_val = create_sequences(emb_val_raw, num_val_raw, y_val_raw, sequence_length)
X_emb_test, X_num_test, y_test = create_sequences(emb_test_raw, num_test_raw, y_test_raw, sequence_length)

# %%
# Inputs
embedding_input = Input(shape=(sequence_length,X_emb_train.shape[2]))   # change 50 to your seq_len
numeric_input = Input(shape=(sequence_length,X_num_train.shape[2]))

# Embeddings branch
x = LSTM(64, return_sequences=True)(embedding_input)
x = LSTM(32)(x)

#numerical branch
z= LSTM(16, return_sequences=True)(numeric_input)
z= LSTM(8)(z)

# Concatenate numeric features
x = Concatenate()([x, z])

# Output
output = Dense(1, activation='sigmoid')(x)

# Build model
model = Model(inputs=[embedding_input, numeric_input], outputs=output)

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 20, 512)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_3       │ (None, 20, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_4 (LSTM)       │ (None, 20, 64)    │    147,712 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_6 (LSTM)       │ (None, 20, 16)    │      1,472 │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_5 (LSTM)       │ (None, 32)        │     12,416 │ lstm_4[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_7 (LSTM)       │ (None, 8)         │        800 │ lstm_6[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 40)        │          0 │ lstm_5[0][0],     │
# │ (Concatenate)       │                   │            │ lstm_7[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │         41 │ concatenate_1[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 162,441 (634.54 KB)
#  Trainable params: 162,441 (634.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    [X_emb_train, X_num_train],  # inputs
    y_train,                        # labels
    validation_data=([X_emb_val, X_num_val], y_val),
    epochs=200,                      # start with 10, can increase
    batch_size=32,                  # tune depending on memory
    shuffle=False
)

model.save("best_model_LSTM.keras")
# Out:
# Epoch 1/200
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_8', 'keras_tensor_9']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - accuracy: 0.4734 - loss: 0.6939 - val_accuracy: 0.4592 - val_loss: 0.6963
# Epoch 2/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5632 - loss: 0.6897 - val_accuracy: 0.4490 - val_loss: 0.6996
# Epoch 3/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5329 - loss: 0.6888 - val_accuracy: 0.4490 - val_loss: 0.7010
# Epoch 4/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5682 - loss: 0.6863 - val_accuracy: 0.5000 - val_loss: 0.7013
# Epoch 5/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5606 - loss: 0.6825 - val_accuracy: 0.5102 - val_loss: 0.7026
# Epoch 6/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5544 - loss: 0.6762 - val_accuracy: 0.4286 - val_loss: 0.7083
# Epoch 7/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5597 - loss: 0.6619 - val_accuracy: 0.4796 - val_loss: 0.7365
# Epoch 8/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5970 - loss: 0.6633 - val_accuracy: 0.4796 - val_loss: 0.7130
# Epoch 9/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6144 - loss: 0.6645 - val_accuracy: 0.4898 - val_loss: 0.7276
# Epoch 10/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6060 - loss: 0.6494 - val_accuracy: 0.4898 - val_loss: 0.7460
# Epoch 11/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5999 - loss: 0.6370 - val_accuracy: 0.4694 - val_loss: 0.7345
# Epoch 12/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6533 - loss: 0.6286 - val_accuracy: 0.5000 - val_loss: 0.7126
# Epoch 13/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6639 - loss: 0.6184 - val_accuracy: 0.5102 - val_loss: 0.7973
# Epoch 14/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6334 - loss: 0.6336 - val_accuracy: 0.5612 - val_loss: 0.7096
# Epoch 15/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6768 - loss: 0.6017 - val_accuracy: 0.5102 - val_loss: 0.7462
# Epoch 16/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6620 - loss: 0.5906 - val_accuracy: 0.5204 - val_loss: 0.7623
# Epoch 17/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6414 - loss: 0.6326 - val_accuracy: 0.5408 - val_loss: 0.7083
# Epoch 18/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6735 - loss: 0.6070 - val_accuracy: 0.5510 - val_loss: 0.8127
# Epoch 19/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6493 - loss: 0.6313 - val_accuracy: 0.5306 - val_loss: 0.8026
# Epoch 20/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5917 - loss: 0.6890 - val_accuracy: 0.4796 - val_loss: 0.7189
# Epoch 21/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6994 - loss: 0.6052 - val_accuracy: 0.5204 - val_loss: 0.7708
# Epoch 22/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6791 - loss: 0.5823 - val_accuracy: 0.5918 - val_loss: 0.8147
# Epoch 23/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6609 - loss: 0.6145 - val_accuracy: 0.5102 - val_loss: 0.7107
# Epoch 24/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6773 - loss: 0.5969 - val_accuracy: 0.5510 - val_loss: 0.7111
# Epoch 25/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6407 - loss: 0.6143 - val_accuracy: 0.5816 - val_loss: 0.7034
# Epoch 26/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6933 - loss: 0.5702 - val_accuracy: 0.5816 - val_loss: 0.7660
# Epoch 27/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7261 - loss: 0.5631 - val_accuracy: 0.5714 - val_loss: 0.7760
# Epoch 28/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7388 - loss: 0.5699 - val_accuracy: 0.5204 - val_loss: 0.7707
# Epoch 29/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6340 - loss: 0.6288 - val_accuracy: 0.5408 - val_loss: 0.7084
# Epoch 30/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6756 - loss: 0.5681 - val_accuracy: 0.5714 - val_loss: 0.7837
# Epoch 31/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7260 - loss: 0.5324 - val_accuracy: 0.5612 - val_loss: 0.8077
# Epoch 32/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7369 - loss: 0.5269 - val_accuracy: 0.5816 - val_loss: 0.8141
# Epoch 33/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7073 - loss: 0.5294 - val_accuracy: 0.5816 - val_loss: 0.8641
# Epoch 34/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7243 - loss: 0.5066 - val_accuracy: 0.5612 - val_loss: 0.8817
# Epoch 35/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7656 - loss: 0.5117 - val_accuracy: 0.5612 - val_loss: 0.7430
# Epoch 36/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7080 - loss: 0.5461 - val_accuracy: 0.5408 - val_loss: 0.7110
# Epoch 37/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6809 - loss: 0.5812 - val_accuracy: 0.5408 - val_loss: 0.7373
# Epoch 38/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7342 - loss: 0.5303 - val_accuracy: 0.5408 - val_loss: 0.8841
# Epoch 39/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7186 - loss: 0.5230 - val_accuracy: 0.5408 - val_loss: 0.9284
# Epoch 40/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7332 - loss: 0.5166 - val_accuracy: 0.5612 - val_loss: 0.8886
# Epoch 41/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7657 - loss: 0.4829 - val_accuracy: 0.5000 - val_loss: 1.0546
# Epoch 42/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6652 - loss: 0.6718 - val_accuracy: 0.5714 - val_loss: 0.7186
# Epoch 43/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6994 - loss: 0.5591 - val_accuracy: 0.5306 - val_loss: 0.7087
# Epoch 44/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7474 - loss: 0.5147 - val_accuracy: 0.5204 - val_loss: 0.9021
# Epoch 45/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7587 - loss: 0.4732 - val_accuracy: 0.5510 - val_loss: 0.8658
# Epoch 46/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7866 - loss: 0.4737 - val_accuracy: 0.5408 - val_loss: 0.9468
# Epoch 47/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7348 - loss: 0.4709 - val_accuracy: 0.5510 - val_loss: 0.9083
# Epoch 48/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7447 - loss: 0.4941 - val_accuracy: 0.5102 - val_loss: 1.0454
# Epoch 49/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7944 - loss: 0.4428 - val_accuracy: 0.5510 - val_loss: 0.9210
# Epoch 50/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6677 - loss: 0.5693 - val_accuracy: 0.5306 - val_loss: 0.7984
# Epoch 51/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7352 - loss: 0.5231 - val_accuracy: 0.5612 - val_loss: 0.8302
# Epoch 52/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7632 - loss: 0.4680 - val_accuracy: 0.5306 - val_loss: 0.9745
# Epoch 53/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7746 - loss: 0.4277 - val_accuracy: 0.5204 - val_loss: 1.0214
# Epoch 54/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8173 - loss: 0.4065 - val_accuracy: 0.5510 - val_loss: 0.9967
# Epoch 55/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8165 - loss: 0.4187 - val_accuracy: 0.4796 - val_loss: 1.2704
# Epoch 56/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7368 - loss: 0.5251 - val_accuracy: 0.5204 - val_loss: 0.7781
# Epoch 57/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7090 - loss: 0.5566 - val_accuracy: 0.5510 - val_loss: 0.8081
# Epoch 58/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6834 - loss: 0.5281 - val_accuracy: 0.5306 - val_loss: 0.8353
# Epoch 59/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7455 - loss: 0.4753 - val_accuracy: 0.5102 - val_loss: 1.1306
# Epoch 60/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8177 - loss: 0.4288 - val_accuracy: 0.5204 - val_loss: 0.9557
# Epoch 61/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7601 - loss: 0.4581 - val_accuracy: 0.4898 - val_loss: 1.1490
# Epoch 62/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8130 - loss: 0.4328 - val_accuracy: 0.5102 - val_loss: 1.0056
# Epoch 63/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7935 - loss: 0.4107 - val_accuracy: 0.5000 - val_loss: 1.2006
# Epoch 64/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8139 - loss: 0.3788 - val_accuracy: 0.5000 - val_loss: 1.1066
# Epoch 65/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8261 - loss: 0.3914 - val_accuracy: 0.5306 - val_loss: 1.3466
# Epoch 66/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7323 - loss: 0.5081 - val_accuracy: 0.5204 - val_loss: 1.0447
# Epoch 67/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6382 - loss: 0.6621 - val_accuracy: 0.5306 - val_loss: 1.0200
# Epoch 68/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7316 - loss: 0.5106 - val_accuracy: 0.5102 - val_loss: 0.8179
# Epoch 69/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7757 - loss: 0.4717 - val_accuracy: 0.5408 - val_loss: 0.9366
# Epoch 70/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8341 - loss: 0.3922 - val_accuracy: 0.4796 - val_loss: 1.3008
# Epoch 71/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8452 - loss: 0.3644 - val_accuracy: 0.4898 - val_loss: 1.3015
# Epoch 72/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8298 - loss: 0.3332 - val_accuracy: 0.4694 - val_loss: 1.2847
# Epoch 73/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8310 - loss: 0.3442 - val_accuracy: 0.5000 - val_loss: 1.5829
# Epoch 74/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8066 - loss: 0.3967 - val_accuracy: 0.5204 - val_loss: 1.1360
# Epoch 75/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7437 - loss: 0.5250 - val_accuracy: 0.5204 - val_loss: 0.9030
# Epoch 76/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7542 - loss: 0.4545 - val_accuracy: 0.5306 - val_loss: 1.1463
# Epoch 77/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7519 - loss: 0.4525 - val_accuracy: 0.5204 - val_loss: 1.0918
# Epoch 78/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7741 - loss: 0.4233 - val_accuracy: 0.5102 - val_loss: 1.2997
# Epoch 79/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8054 - loss: 0.3703 - val_accuracy: 0.5408 - val_loss: 1.3634
# Epoch 80/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7755 - loss: 0.4084 - val_accuracy: 0.5306 - val_loss: 0.9749
# Epoch 81/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8308 - loss: 0.3884 - val_accuracy: 0.4898 - val_loss: 1.3127
# Epoch 82/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8502 - loss: 0.3361 - val_accuracy: 0.5408 - val_loss: 1.2050
# Epoch 83/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8429 - loss: 0.3761 - val_accuracy: 0.4796 - val_loss: 1.4478
# Epoch 84/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8388 - loss: 0.3543 - val_accuracy: 0.4898 - val_loss: 1.4098
# Epoch 85/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8786 - loss: 0.2964 - val_accuracy: 0.5102 - val_loss: 1.4154
# Epoch 86/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8017 - loss: 0.3653 - val_accuracy: 0.5000 - val_loss: 1.2097
# Epoch 87/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7883 - loss: 0.4144 - val_accuracy: 0.5000 - val_loss: 1.0842
# Epoch 88/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8315 - loss: 0.3907 - val_accuracy: 0.4796 - val_loss: 1.6762
# Epoch 89/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8130 - loss: 0.3904 - val_accuracy: 0.5408 - val_loss: 1.0500
# Epoch 90/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8063 - loss: 0.3806 - val_accuracy: 0.4490 - val_loss: 1.5211
# Epoch 91/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8546 - loss: 0.3515 - val_accuracy: 0.5204 - val_loss: 1.3238
# Epoch 92/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8468 - loss: 0.3209 - val_accuracy: 0.4592 - val_loss: 1.6090
# Epoch 93/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8661 - loss: 0.2939 - val_accuracy: 0.5612 - val_loss: 1.0730
# Epoch 94/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7783 - loss: 0.4780 - val_accuracy: 0.4898 - val_loss: 1.2379
# Epoch 95/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8200 - loss: 0.3780 - val_accuracy: 0.5000 - val_loss: 1.2609
# Epoch 96/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8351 - loss: 0.3304 - val_accuracy: 0.4796 - val_loss: 1.0766
# Epoch 97/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8310 - loss: 0.3498 - val_accuracy: 0.4796 - val_loss: 1.4657
# Epoch 98/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8320 - loss: 0.3333 - val_accuracy: 0.5102 - val_loss: 1.3819
# Epoch 99/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8178 - loss: 0.3786 - val_accuracy: 0.5000 - val_loss: 1.5825
# Epoch 100/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8573 - loss: 0.3037 - val_accuracy: 0.5306 - val_loss: 1.3012
# Epoch 101/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8625 - loss: 0.3221 - val_accuracy: 0.4796 - val_loss: 1.5872
# Epoch 102/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8536 - loss: 0.3088 - val_accuracy: 0.5306 - val_loss: 1.3374
# Epoch 103/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7414 - loss: 0.4856 - val_accuracy: 0.5204 - val_loss: 1.1473
# Epoch 104/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7931 - loss: 0.4030 - val_accuracy: 0.5102 - val_loss: 1.2131
# Epoch 105/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8320 - loss: 0.3303 - val_accuracy: 0.5102 - val_loss: 1.5015
# Epoch 106/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8589 - loss: 0.2901 - val_accuracy: 0.5306 - val_loss: 1.1951
# Epoch 107/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8046 - loss: 0.3791 - val_accuracy: 0.5102 - val_loss: 1.1728
# Epoch 108/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8178 - loss: 0.3664 - val_accuracy: 0.5000 - val_loss: 1.1863
# Epoch 109/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7584 - loss: 0.4161 - val_accuracy: 0.5102 - val_loss: 1.3323
# Epoch 110/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8643 - loss: 0.2906 - val_accuracy: 0.5102 - val_loss: 1.4833
# Epoch 111/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8563 - loss: 0.2942 - val_accuracy: 0.4694 - val_loss: 1.7287
# Epoch 112/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8313 - loss: 0.3364 - val_accuracy: 0.5102 - val_loss: 1.6410
# Epoch 113/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7926 - loss: 0.3878 - val_accuracy: 0.4694 - val_loss: 1.0634
# Epoch 114/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7579 - loss: 0.4427 - val_accuracy: 0.5102 - val_loss: 1.5347
# Epoch 115/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8356 - loss: 0.3377 - val_accuracy: 0.5510 - val_loss: 1.1881
# Epoch 116/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8641 - loss: 0.3076 - val_accuracy: 0.4796 - val_loss: 1.7914
# Epoch 117/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8643 - loss: 0.2568 - val_accuracy: 0.5408 - val_loss: 1.5705
# Epoch 118/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8769 - loss: 0.2370 - val_accuracy: 0.4694 - val_loss: 1.8955
# Epoch 119/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8802 - loss: 0.2271 - val_accuracy: 0.4694 - val_loss: 1.8425
# Epoch 120/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8779 - loss: 0.2060 - val_accuracy: 0.5306 - val_loss: 1.6210
# Epoch 121/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9029 - loss: 0.2468 - val_accuracy: 0.5000 - val_loss: 1.8198
# Epoch 122/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8701 - loss: 0.2574 - val_accuracy: 0.5102 - val_loss: 1.7600
# Epoch 123/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8296 - loss: 0.3177 - val_accuracy: 0.5408 - val_loss: 1.4500
# Epoch 124/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8556 - loss: 0.2873 - val_accuracy: 0.5102 - val_loss: 1.8564
# Epoch 125/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8756 - loss: 0.2874 - val_accuracy: 0.5204 - val_loss: 1.6269
# Epoch 126/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8737 - loss: 0.2333 - val_accuracy: 0.5204 - val_loss: 1.7148
# Epoch 127/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8648 - loss: 0.2926 - val_accuracy: 0.5714 - val_loss: 1.4381
# Epoch 128/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8337 - loss: 0.3711 - val_accuracy: 0.5510 - val_loss: 1.4634
# Epoch 129/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8421 - loss: 0.3861 - val_accuracy: 0.5306 - val_loss: 1.3504
# Epoch 130/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8817 - loss: 0.2798 - val_accuracy: 0.5000 - val_loss: 1.6813
# Epoch 131/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8932 - loss: 0.2282 - val_accuracy: 0.5204 - val_loss: 1.8365
# Epoch 132/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9041 - loss: 0.2041 - val_accuracy: 0.4898 - val_loss: 1.9307
# Epoch 133/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8838 - loss: 0.2208 - val_accuracy: 0.4796 - val_loss: 1.9654
# Epoch 134/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8680 - loss: 0.2282 - val_accuracy: 0.5000 - val_loss: 1.9500
# Epoch 135/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8806 - loss: 0.2296 - val_accuracy: 0.5000 - val_loss: 2.0961
# Epoch 136/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7921 - loss: 0.4496 - val_accuracy: 0.4796 - val_loss: 1.0647
# Epoch 137/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7245 - loss: 0.5334 - val_accuracy: 0.4898 - val_loss: 1.0346
# Epoch 138/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8109 - loss: 0.3777 - val_accuracy: 0.5204 - val_loss: 1.3890
# Epoch 139/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8650 - loss: 0.2999 - val_accuracy: 0.5000 - val_loss: 1.5993
# Epoch 140/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8791 - loss: 0.2844 - val_accuracy: 0.5000 - val_loss: 1.8474
# Epoch 141/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8609 - loss: 0.3215 - val_accuracy: 0.5204 - val_loss: 1.8659
# Epoch 142/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8780 - loss: 0.2501 - val_accuracy: 0.5000 - val_loss: 1.9623
# Epoch 143/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8481 - loss: 0.3000 - val_accuracy: 0.5408 - val_loss: 1.6921
# Epoch 144/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9004 - loss: 0.2271 - val_accuracy: 0.5306 - val_loss: 1.4752
# Epoch 145/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8693 - loss: 0.2943 - val_accuracy: 0.4898 - val_loss: 2.1190
# Epoch 146/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8490 - loss: 0.3292 - val_accuracy: 0.5510 - val_loss: 1.2542
# Epoch 147/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8454 - loss: 0.3133 - val_accuracy: 0.5102 - val_loss: 1.8204
# Epoch 148/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8605 - loss: 0.2904 - val_accuracy: 0.4490 - val_loss: 1.3130
# Epoch 149/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8214 - loss: 0.3723 - val_accuracy: 0.5408 - val_loss: 1.6377
# Epoch 150/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8917 - loss: 0.2312 - val_accuracy: 0.5102 - val_loss: 1.7926
# Epoch 151/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8644 - loss: 0.2467 - val_accuracy: 0.5102 - val_loss: 2.1397
# Epoch 152/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8955 - loss: 0.2534 - val_accuracy: 0.5510 - val_loss: 1.8358
# Epoch 153/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9267 - loss: 0.1913 - val_accuracy: 0.5204 - val_loss: 2.1433
# Epoch 154/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9088 - loss: 0.1815 - val_accuracy: 0.5306 - val_loss: 1.9404
# Epoch 155/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9173 - loss: 0.1879 - val_accuracy: 0.4796 - val_loss: 2.1571
# Epoch 156/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9020 - loss: 0.1713 - val_accuracy: 0.5306 - val_loss: 2.2681
# Epoch 157/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9234 - loss: 0.1788 - val_accuracy: 0.5408 - val_loss: 1.9256
# Epoch 158/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9172 - loss: 0.1856 - val_accuracy: 0.4898 - val_loss: 2.4397
# Epoch 159/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8969 - loss: 0.1864 - val_accuracy: 0.5306 - val_loss: 2.0246
# Epoch 160/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8984 - loss: 0.2050 - val_accuracy: 0.5000 - val_loss: 2.2667
# Epoch 161/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9285 - loss: 0.1493 - val_accuracy: 0.5204 - val_loss: 2.3000
# Epoch 162/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9296 - loss: 0.1531 - val_accuracy: 0.5204 - val_loss: 2.3372
# Epoch 163/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9352 - loss: 0.1389 - val_accuracy: 0.4898 - val_loss: 2.3681
# Epoch 164/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9275 - loss: 0.1494 - val_accuracy: 0.5102 - val_loss: 2.5964
# Epoch 165/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9301 - loss: 0.1504 - val_accuracy: 0.5102 - val_loss: 2.5437
# Epoch 166/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9137 - loss: 0.2054 - val_accuracy: 0.4388 - val_loss: 2.2633
# Epoch 167/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8300 - loss: 0.3359 - val_accuracy: 0.5408 - val_loss: 1.8593
# Epoch 168/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8622 - loss: 0.2687 - val_accuracy: 0.5408 - val_loss: 1.4428
# Epoch 169/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8236 - loss: 0.3920 - val_accuracy: 0.5204 - val_loss: 1.7839
# Epoch 170/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8137 - loss: 0.4438 - val_accuracy: 0.5204 - val_loss: 1.4703
# Epoch 171/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8822 - loss: 0.2569 - val_accuracy: 0.5000 - val_loss: 2.0002
# Epoch 172/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9097 - loss: 0.1904 - val_accuracy: 0.5102 - val_loss: 2.0300
# Epoch 173/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9081 - loss: 0.1803 - val_accuracy: 0.4898 - val_loss: 2.3142
# Epoch 174/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8981 - loss: 0.1931 - val_accuracy: 0.5204 - val_loss: 1.9260
# Epoch 175/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9201 - loss: 0.1813 - val_accuracy: 0.4796 - val_loss: 2.2328
# Epoch 176/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8769 - loss: 0.2229 - val_accuracy: 0.5306 - val_loss: 2.1884
# Epoch 177/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8820 - loss: 0.1997 - val_accuracy: 0.5000 - val_loss: 1.9223
# Epoch 178/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8941 - loss: 0.2411 - val_accuracy: 0.5408 - val_loss: 2.1220
# Epoch 179/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9256 - loss: 0.1524 - val_accuracy: 0.5204 - val_loss: 2.2957
# Epoch 180/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9186 - loss: 0.1440 - val_accuracy: 0.5306 - val_loss: 2.3146
# Epoch 181/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9165 - loss: 0.1539 - val_accuracy: 0.5000 - val_loss: 2.5709
# Epoch 182/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9310 - loss: 0.1386 - val_accuracy: 0.5408 - val_loss: 2.3766
# Epoch 183/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9447 - loss: 0.1226 - val_accuracy: 0.5306 - val_loss: 2.5936
# Epoch 184/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9451 - loss: 0.1151 - val_accuracy: 0.5102 - val_loss: 2.6065
# Epoch 185/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9370 - loss: 0.1103 - val_accuracy: 0.5102 - val_loss: 2.7084
# Epoch 186/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9451 - loss: 0.1059 - val_accuracy: 0.5102 - val_loss: 2.6997
# Epoch 187/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9451 - loss: 0.1016 - val_accuracy: 0.5102 - val_loss: 2.7963
# Epoch 188/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9533 - loss: 0.0980 - val_accuracy: 0.5000 - val_loss: 2.8272
# Epoch 189/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9533 - loss: 0.0945 - val_accuracy: 0.4898 - val_loss: 2.9325
# Epoch 190/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9533 - loss: 0.0905 - val_accuracy: 0.4796 - val_loss: 2.9741
# Epoch 191/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9660 - loss: 0.0878 - val_accuracy: 0.5102 - val_loss: 2.8879
# Epoch 192/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9597 - loss: 0.0940 - val_accuracy: 0.5102 - val_loss: 2.8522
# Epoch 193/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9589 - loss: 0.0963 - val_accuracy: 0.5000 - val_loss: 2.5237
# Epoch 194/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8202 - loss: 0.4069 - val_accuracy: 0.5306 - val_loss: 1.6401
# Epoch 195/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8170 - loss: 0.3659 - val_accuracy: 0.5204 - val_loss: 1.9771
# Epoch 196/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7942 - loss: 0.4440 - val_accuracy: 0.5000 - val_loss: 1.4273
# Epoch 197/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7552 - loss: 0.4650 - val_accuracy: 0.5102 - val_loss: 0.9850
# Epoch 198/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6443 - loss: 0.6538 - val_accuracy: 0.4796 - val_loss: 0.7579
# Epoch 199/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6506 - loss: 0.6117 - val_accuracy: 0.4796 - val_loss: 0.7999
# Epoch 200/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6437 - loss: 0.5989 - val_accuracy: 0.4796 - val_loss: 0.8257

# %%
thresholds=np.arange(0.0,1.01,0.1)
f1_scores=[]
best_f1=0

#selecting best threshold on val data

y_prob = model.predict([X_emb_val, X_num_val])
for threshold in thresholds:
    y_pred_tr = (y_prob > threshold).astype(int)
    report=classification_report(y_val, y_pred_tr, output_dict=True)
    f1_scores.append(report['macro avg']['f1-score'])

#deciding the best index    
f1_score=max(f1_scores)
index_tr=f1_scores.index(f1_score)
threshold=thresholds[index_tr]

#now deciding F1 on test data with the decided best threshold
y_prob = model.predict([X_emb_test, X_num_test])
y_pred_tr = (y_prob > threshold).astype(int)
report=classification_report(y_test, y_pred_tr, output_dict=True)
f1=report['macro avg']['f1-score']
print(f"Best Result is f1 {f1} at threshold {threshold}")
results["with Window"]=[f1, threshold, report]
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Best Result is f1 0.5306122448979592 at threshold 0.7000000000000001
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
y_prob = model.predict([X_emb_test, X_num_test])
y_pred = (y_prob > threshold).astype(int)
print(classification_report(y_test, y_pred))

print("confusion_matrix is:")
cm=confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, 
            annot=True, 
            fmt='d', 
            cmap='Blues',
            xticklabels=["Negative", "Positive"],
            yticklabels=["Negative", "Positive"])

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#               precision    recall  f1-score   support
#
#            0       0.45      0.65      0.53        20
#            1       0.65      0.45      0.53        29
#
#     accuracy                           0.53        49
#    macro avg       0.55      0.55      0.53        49
# weighted avg       0.57      0.53      0.53        49
#
# confusion_matrix is:

# %%
auc=roc_auc_score(y_test, y_prob)

fpr, tpr, thresholds = roc_curve(y_test, y_prob)

plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # random line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.title("ROC for LSTM with 512 embeddings and 6 numerical features")
plt.show()

# %%
labels = list(results.keys())

f1_scores = [v[0] for v in results.values()]
thresholds = [v[1] for v in results.values()]

bars = plt.bar(labels, f1_scores, color=["steelblue", "orange"])

plt.ylabel("Untuned LSTM F1 Score")
plt.title("F1 Score Comparison")
plt.ylim(0, 1)

# Add F1 + threshold as text
for bar, f1, th in zip(bars, f1_scores, thresholds):
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        f"F1={f1:.3f}\nth={th:.2f}",
        ha="center",
        va="bottom",
        fontsize=10
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# Conclusion: LSTM works better with rolling window
