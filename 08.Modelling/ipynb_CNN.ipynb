# %% [markdown]
# Testing Window or non Window Approach on CNN then LSTM Layer

# %%
import pandas as pd
from sklearn.metrics import classification_report,roc_auc_score, confusion_matrix, roc_curve
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping
import random
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import AUC

#CNN modules
from tensorflow.keras.layers import Conv1D, MaxPooling1D

def set_seed(seed=42):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    random.seed(seed)

set_seed(42)
results={}
scale=StandardScaler()
# Out:
# 2026-05-28 17:30:59.404682: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#import dataframe
df_modelling=pd.read_parquet("../df_modelling.parquet")

# %% [markdown]
# Without Rolling Window:

# %%
#creating market vector
# 'Stock_Date', 'Closing Price($)', 'relative difference',
#        'comment_published_at_median_YMD', 'number_of_comments_at_date',
#        'comment_likes_agg', 'comment_embeddings_agg', 'comment_sentiment_agg',
#        'sentiment_tensor', 'videos_text_embeddings', 'TargetVariable:Up/Down'
numerical_columns=['Closing Price($) lag1',
'relative difference lag1',
         'number_of_comments_at_date',
    'comment_likes_agg',
    'comment_sentiment_agg',
     'sentiment_tensor']

print(df_modelling.columns)


#concating the embeddings separately
df_modelling['embeddings_vector']=df_modelling.apply(lambda row: np.concatenate((row['comment_embeddings_agg'], row['videos_text_embeddings'])), axis=1)
# Out:
# Index(['Stock_Date', 'Closing Price($)', 'relative difference',
#        'comment_published_at_YMD', 'number_of_comments_at_date',
#        'comment_likes_agg', 'comment_embeddings_agg', 'comment_sentiment_agg',
#        'sentiment_tensor', 'videos_text_embeddings', 'Difference',
#        'videos_text_embeddings_window', 'TargetVariable:Up/Down',
#        'Closing Price($) lag1', 'relative difference lag1',
#        'Calendar_Diff_Days'],
#       dtype='object')

# %%
#function for creating sequences
def create_sequences(embeddings, numeric, target, sequence_length):
    X_emb_seq = []
    X_num_seq = []
    y_seq = []

    for i in range(sequence_length, len(embeddings)):
        X_emb_seq.append(embeddings[i-sequence_length:i])
        X_num_seq.append(numeric[i-sequence_length:i])
        y_seq.append(target[i])

    return (
        np.array(X_emb_seq),
        np.array(X_num_seq),
        np.array(y_seq)
    )

# %%
sequence_length = 20  # timesteps

#splitting data
embeddings_array = np.stack(df_modelling['embeddings_vector'])
numerical_values = np.stack(df_modelling[numerical_columns].values)
y = df_modelling['TargetVariable:Up/Down'].values


N = len(embeddings_array)
#train 70% val 20% test 10%
train_end = int(N * 0.7)
val_end = int(N * 0.9)

# TRAIN
emb_train_raw = embeddings_array[:train_end]
num_train_raw = numerical_values[:train_end]
y_train_raw   = y[:train_end]

# VALIDATION
emb_val_raw = embeddings_array[train_end-sequence_length:val_end]
num_val_raw = numerical_values[train_end-sequence_length:val_end]
y_val_raw   = y[train_end-sequence_length:val_end]

# TEST
emb_test_raw = embeddings_array[val_end-sequence_length:]
num_test_raw = numerical_values[val_end-sequence_length:]
y_test_raw   = y[val_end-sequence_length:]


num_train_raw = scale.fit_transform(num_train_raw)
num_val_raw = scale.transform(num_val_raw)
num_test_raw = scale.transform(num_test_raw)

# %%
#LSTM will look 20 steps in the past
X_emb_train, X_num_train, y_train = create_sequences(emb_train_raw, num_train_raw, y_train_raw, sequence_length)
X_emb_val, X_num_val, y_val = create_sequences(emb_val_raw, num_val_raw, y_val_raw, sequence_length)
X_emb_test, X_num_test, y_test = create_sequences(emb_test_raw, num_test_raw, y_test_raw, sequence_length)

# %%
# Inputs
embedding_input = Input(shape=(sequence_length,X_emb_train.shape[2]))   # change 50 to your seq_len
numeric_input = Input(shape=(sequence_length,X_num_train.shape[2]))

# Embeddings branch: CNN 
x = Conv1D(filters=128, kernel_size=3, activation='relu', padding='same')(embedding_input)
x = MaxPooling1D(pool_size=2)(x) 
x = LSTM(32,return_sequences=True)(x)
x = LSTM(16)(x)

#numerical branch
z= LSTM(8)(numeric_input)

# Concatenate numeric features
x = Concatenate()([x, z])

# Output
output = Dense(1, activation='sigmoid')(x)

# Build model
model = Model(inputs=[embedding_input, numeric_input], outputs=output)

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 20, 512)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 20, 128)   │    196,736 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 10, 128)   │          0 │ conv1d[0][0]      │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 10, 32)    │     20,608 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 20, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ (None, 16)        │      3,136 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 8)         │        480 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 24)        │          0 │ lstm_1[0][0],     │
# │ (Concatenate)       │                   │            │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1)         │         25 │ concatenate[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 220,985 (863.22 KB)
#  Trainable params: 220,985 (863.22 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history=model.fit(
    [X_emb_train, X_num_train],  # inputs
    y_train,                        # labels
    validation_data=([X_emb_val, X_num_val], y_val),
    epochs=200,                      # start with 10, can increase
    batch_size=32,                  # tune depending on memory
    shuffle=False
)
# Out:
# Epoch 1/200
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor', 'keras_tensor_1']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.5020 - loss: 0.6950 - val_accuracy: 0.5102 - val_loss: 0.6880
# Epoch 2/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5439 - loss: 0.6904 - val_accuracy: 0.4898 - val_loss: 0.6906
# Epoch 3/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5621 - loss: 0.6906 - val_accuracy: 0.4898 - val_loss: 0.6908
# Epoch 4/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5739 - loss: 0.6871 - val_accuracy: 0.5000 - val_loss: 0.6901
# Epoch 5/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5914 - loss: 0.6815 - val_accuracy: 0.5102 - val_loss: 0.6910
# Epoch 6/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5975 - loss: 0.6709 - val_accuracy: 0.5408 - val_loss: 0.6959
# Epoch 7/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6062 - loss: 0.6558 - val_accuracy: 0.5306 - val_loss: 0.7092
# Epoch 8/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6350 - loss: 0.6537 - val_accuracy: 0.5306 - val_loss: 0.7576
# Epoch 9/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5271 - loss: 0.7228 - val_accuracy: 0.5306 - val_loss: 0.7157
# Epoch 10/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5105 - loss: 0.7132 - val_accuracy: 0.5408 - val_loss: 0.7026
# Epoch 11/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5270 - loss: 0.6830 - val_accuracy: 0.4796 - val_loss: 0.6892
# Epoch 12/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5888 - loss: 0.6720 - val_accuracy: 0.4694 - val_loss: 0.7026
# Epoch 13/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5372 - loss: 0.6739 - val_accuracy: 0.4898 - val_loss: 0.6932
# Epoch 14/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6292 - loss: 0.6617 - val_accuracy: 0.5000 - val_loss: 0.6957
# Epoch 15/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6242 - loss: 0.6522 - val_accuracy: 0.5306 - val_loss: 0.6976
# Epoch 16/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6326 - loss: 0.6422 - val_accuracy: 0.4796 - val_loss: 0.7018
# Epoch 17/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6276 - loss: 0.6273 - val_accuracy: 0.5102 - val_loss: 0.7149
# Epoch 18/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6242 - loss: 0.6232 - val_accuracy: 0.4898 - val_loss: 0.8548
# Epoch 19/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6313 - loss: 0.6362 - val_accuracy: 0.5510 - val_loss: 0.7224
# Epoch 20/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5595 - loss: 0.6951 - val_accuracy: 0.4898 - val_loss: 0.7332
# Epoch 21/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6654 - loss: 0.6285 - val_accuracy: 0.4694 - val_loss: 0.7317
# Epoch 22/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.
200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.4592 - val_loss: 2.2607
# Epoch 161/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.4592 - val_loss: 2.2780
# Epoch 162/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.4592 - val_loss: 2.2918
# Epoch 163/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.4490 - val_loss: 2.3031
# Epoch 164/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.4490 - val_loss: 2.3138
# Epoch 165/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.4490 - val_loss: 2.3247
# Epoch 166/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.4490 - val_loss: 2.3357
# Epoch 167/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.4490 - val_loss: 2.3470
# Epoch 168/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.4490 - val_loss: 2.3584
# Epoch 169/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.4490 - val_loss: 2.3698
# Epoch 170/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.4592 - val_loss: 2.3813
# Epoch 171/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.4592 - val_loss: 2.3930
# Epoch 172/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.4592 - val_loss: 2.4048
# Epoch 173/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.4592 - val_loss: 2.4168
# Epoch 174/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.4592 - val_loss: 2.4287
# Epoch 175/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.4694 - val_loss: 2.4402
# Epoch 176/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.4694 - val_loss: 2.4513
# Epoch 177/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.4694 - val_loss: 2.4617
# Epoch 178/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.4694 - val_loss: 2.4716
# Epoch 179/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.4694 - val_loss: 2.4813
# Epoch 180/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.4694 - val_loss: 2.4907
# Epoch 181/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.4694 - val_loss: 2.4998
# Epoch 182/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.4694 - val_loss: 2.5088
# Epoch 183/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.4694 - val_loss: 2.5177
# Epoch 184/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.4694 - val_loss: 2.5266
# Epoch 185/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.4796 - val_loss: 2.5357
# Epoch 186/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.4796 - val_loss: 2.5447
# Epoch 187/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.4694 - val_loss: 2.5536
# Epoch 188/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.4694 - val_loss: 2.5625
# Epoch 189/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.4694 - val_loss: 2.5713
# Epoch 190/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.4694 - val_loss: 2.5801
# Epoch 191/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.4694 - val_loss: 2.5888
# Epoch 192/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.4694 - val_loss: 2.5974
# Epoch 193/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.4694 - val_loss: 2.6060
# Epoch 194/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.4694 - val_loss: 2.6146
# Epoch 195/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.4694 - val_loss: 2.6231
# Epoch 196/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.4694 - val_loss: 2.6315
# Epoch 197/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.4694 - val_loss: 2.6398
# Epoch 198/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.4694 - val_loss: 2.6481
# Epoch 199/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.4796 - val_loss: 2.6563
# Epoch 200/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.4796 - val_loss: 2.6645

# %%
thresholds=np.arange(0.0,1.01,0.1)
f1_scores=[]
best_f1=0

#selecting best threshold on val data

y_prob = model.predict([X_emb_val, X_num_val])
for threshold in thresholds:
    y_pred_tr = (y_prob > threshold).astype(int)
    report=classification_report(y_val, y_pred_tr, output_dict=True)
    f1_scores.append(report['macro avg']['f1-score'])

#deciding the best index    
f1_score=max(f1_scores)
index_tr=f1_scores.index(f1_score)
threshold=thresholds[index_tr]

#now deciding F1 on test data with the decided best threshold
y_prob = model.predict([X_emb_test, X_num_test])
y_pred_tr = (y_prob > threshold).astype(int)
report=classification_report(y_test, y_pred_tr, output_dict=True)
f1=report['macro avg']['f1-score']
print(f"Best Result is f1 {f1} at threshold {threshold}")
results["without Window"]=[f1, threshold, report]
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Best Result is f1 0.5298289528577389 at threshold 0.30000000000000004
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
y_prob = model.predict([X_emb_test, X_num_test])
y_pred = (y_prob > threshold).astype(int)
print(classification_report(y_test, y_pred))

print("confusion_matrix is:")
cm=confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, 
            annot=True, 
            fmt='d', 
            cmap='Blues',
            xticklabels=["Negative", "Positive"],
            yticklabels=["Negative", "Positive"])

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.45      0.70      0.55        20
#            1       0.67      0.41      0.51        29
#
#     accuracy                           0.53        49
#    macro avg       0.56      0.56      0.53        49
# weighted avg       0.58      0.53      0.53        49
#
# confusion_matrix is:

# %%
auc=roc_auc_score(y_test, y_prob)

fpr, tpr, thresholds = roc_curve(y_test, y_prob)

plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # random line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.title("ROC for LSTM with 512 embeddings and 6 numerical features")
plt.show()

# %% [markdown]
# With Rolling Window:

# %%
#creating market vector
# 'Stock_Date', 'Closing Price($)', 'relative difference',
#        'comment_published_at_median_YMD', 'number_of_comments_at_date',
#        'comment_likes_agg', 'comment_embeddings_agg', 'comment_sentiment_agg',
#        'sentiment_tensor', 'videos_text_embeddings', 'TargetVariable:Up/Down'
numerical_columns=['Closing Price($) lag1',
'relative difference lag1',
         'number_of_comments_at_date',
    'comment_likes_agg',
    'comment_sentiment_agg',
     'sentiment_tensor']

print(df_modelling.columns)


#concating the embeddings separately
df_modelling['embeddings_vector']=df_modelling.apply(lambda row: np.concatenate((row['comment_embeddings_agg'], row['videos_text_embeddings_window'])), axis=1)
# Out:
# Index(['Stock_Date', 'Closing Price($)', 'relative difference',
#        'comment_published_at_YMD', 'number_of_comments_at_date',
#        'comment_likes_agg', 'comment_embeddings_agg', 'comment_sentiment_agg',
#        'sentiment_tensor', 'videos_text_embeddings', 'Difference',
#        'videos_text_embeddings_window', 'TargetVariable:Up/Down',
#        'Closing Price($) lag1', 'relative difference lag1',
#        'Calendar_Diff_Days', 'embeddings_vector'],
#       dtype='object')

# %%
#function for creating sequences
def create_sequences(embeddings, numeric, target, sequence_length):
    X_emb_seq = []
    X_num_seq = []
    y_seq = []

    for i in range(sequence_length, len(embeddings)):
        X_emb_seq.append(embeddings[i-sequence_length:i])
        X_num_seq.append(numeric[i-sequence_length:i])
        y_seq.append(target[i])

    return (
        np.array(X_emb_seq),
        np.array(X_num_seq),
        np.array(y_seq)
    )

# %%
sequence_length = 20  # timesteps

#splitting data
embeddings_array = np.stack(df_modelling['embeddings_vector'])
numerical_values = np.stack(df_modelling[numerical_columns].values)
y = df_modelling['TargetVariable:Up/Down'].values


N = len(embeddings_array)
#train 70% val 20% test 10%
train_end = int(N * 0.7)
val_end = int(N * 0.9)

# TRAIN
emb_train_raw = embeddings_array[:train_end]
num_train_raw = numerical_values[:train_end]
y_train_raw   = y[:train_end]

# VALIDATION
emb_val_raw = embeddings_array[train_end-sequence_length:val_end]
num_val_raw = numerical_values[train_end-sequence_length:val_end]
y_val_raw   = y[train_end-sequence_length:val_end]

# TEST
emb_test_raw = embeddings_array[val_end-sequence_length:]
num_test_raw = numerical_values[val_end-sequence_length:]
y_test_raw   = y[val_end-sequence_length:]

num_train_raw = scale.fit_transform(num_train_raw)
num_val_raw = scale.transform(num_val_raw)
num_test_raw = scale.transform(num_test_raw)

# %%
#LSTM will look 20 steps in the past
X_emb_train, X_num_train, y_train = create_sequences(emb_train_raw, num_train_raw, y_train_raw, sequence_length)
X_emb_val, X_num_val, y_val = create_sequences(emb_val_raw, num_val_raw, y_val_raw, sequence_length)
X_emb_test, X_num_test, y_test = create_sequences(emb_test_raw, num_test_raw, y_test_raw, sequence_length)

# %%
# Inputs
embedding_input = Input(shape=(sequence_length,X_emb_train.shape[2]))   # change 50 to your seq_len
numeric_input = Input(shape=(sequence_length,X_num_train.shape[2]))

# Embeddings branch: CNN 
x = Conv1D(filters=128, kernel_size=3, activation='relu', padding='same')(embedding_input)
x = MaxPooling1D(pool_size=2)(x) 
x = LSTM(32,return_sequences=True)(x)
x = LSTM(16)(x)

#numerical branch
z= LSTM(8)(numeric_input)

# Concatenate numeric features
x = Concatenate()([x, z])

# Output
output = Dense(1, activation='sigmoid')(x)

# Build model
model = Model(inputs=[embedding_input, numeric_input], outputs=output)

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 20, 512)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 20, 128)   │    196,736 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 10, 128)   │          0 │ conv1d_1[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ (None, 10, 32)    │     20,608 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_3       │ (None, 20, 6)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_4 (LSTM)       │ (None, 16)        │      3,136 │ lstm_3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_5 (LSTM)       │ (None, 8)         │        480 │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 24)        │          0 │ lstm_4[0][0],     │
# │ (Concatenate)       │                   │            │ lstm_5[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │         25 │ concatenate_1[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 220,985 (863.22 KB)
#  Trainable params: 220,985 (863.22 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    [X_emb_train, X_num_train],  # inputs
    y_train,                        # labels
    validation_data=([X_emb_val, X_num_val], y_val),
    epochs=200,                      # start with 10, can increase
    batch_size=32,                  # tune depending on memory
    shuffle=False,
)
#saving model for fururee reference

model.save("best_model_CNN-LSTM.keras")
# Out:
# Epoch 1/200
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_9', 'keras_tensor_10']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.4759 - loss: 0.6986 - val_accuracy: 0.4694 - val_loss: 0.6964
# Epoch 2/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5062 - loss: 0.6936 - val_accuracy: 0.4388 - val_loss: 0.6995
# Epoch 3/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5217 - loss: 0.6921 - val_accuracy: 0.4592 - val_loss: 0.6996
# Epoch 4/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5349 - loss: 0.6886 - val_accuracy: 0.4796 - val_loss: 0.6995
# Epoch 5/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5134 - loss: 0.6840 - val_accuracy: 0.5000 - val_loss: 0.7004
# Epoch 6/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5594 - loss: 0.6759 - val_accuracy: 0.5102 - val_loss: 0.7053
# Epoch 7/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5758 - loss: 0.6599 - val_accuracy: 0.5204 - val_loss: 0.7205
# Epoch 8/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5356 - loss: 0.7011 - val_accuracy: 0.5000 - val_loss: 0.7381
# Epoch 9/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5944 - loss: 0.6608 - val_accuracy: 0.4490 - val_loss: 0.7068
# Epoch 10/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5923 - loss: 0.6459 - val_accuracy: 0.4796 - val_loss: 0.7077
# Epoch 11/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6332 - loss: 0.6380 - val_accuracy: 0.5306 - val_loss: 0.7302
# Epoch 12/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6105 - loss: 0.6652 - val_accuracy: 0.4694 - val_loss: 0.7350
# Epoch 13/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6329 - loss: 0.6408 - val_accuracy: 0.4388 - val_loss: 0.7189
# Epoch 14/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6571 - loss: 0.6212 - val_accuracy: 0.4694 - val_loss: 0.7729
# Epoch 15/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6778 - loss: 0.6078 - val_accuracy: 0.4898 - val_loss: 0.7492
# Epoch 16/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6881 - loss: 0.5903 - val_accuracy: 0.4796 - val_loss: 0.7279
# Epoch 17/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6361 - loss: 0.6356 - val_accuracy: 0.5306 - val_loss: 0.7103
# Epoch 18/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6452 - loss: 0.6050 - val_accuracy: 0.4898 - val_loss: 0.8171
# Epoch 19/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7088 - loss: 0.5754 - val_accuracy: 0.5204 - val_loss: 0.7496
# Epoch 20/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.
200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9911 - loss: 0.0774 - val_accuracy: 0.5102 - val_loss: 1.4994
# Epoch 53/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9911 - loss: 0.0588 - val_accuracy: 0.5306 - val_loss: 1.6089
# Epoch 54/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9837 - loss: 0.0515 - val_accuracy: 0.5102 - val_loss: 1.6816
# Epoch 55/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9919 - loss: 0.0377 - val_accuracy: 0.5204 - val_loss: 1.7822
# Epoch 56/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0226 - val_accuracy: 0.5306 - val_loss: 1.8481
# Epoch 57/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9992 - loss: 0.0253 - val_accuracy: 0.4592 - val_loss: 1.9596
# Epoch 58/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9956 - loss: 0.0310 - val_accuracy: 0.5102 - val_loss: 1.9621
# Epoch 59/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9922 - loss: 0.0280 - val_accuracy: 0.5204 - val_loss: 1.9008
# Epoch 60/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9916 - loss: 0.0347 - val_accuracy: 0.5102 - val_loss: 1.7879
# Epoch 61/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8917 - loss: 0.2253 - val_accuracy: 0.5510 - val_loss: 1.7106
# Epoch 62/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9474 - loss: 0.1257 - val_accuracy: 0.4898 - val_loss: 1.6323
# Epoch 63/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9536 - loss: 0.1223 - val_accuracy: 0.5000 - val_loss: 1.1574
# Epoch 64/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9574 - loss: 0.1441 - val_accuracy: 0.4694 - val_loss: 1.5438
# Epoch 65/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9565 - loss: 0.1067 - val_accuracy: 0.5000 - val_loss: 1.7102
# Epoch 66/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9901 - loss: 0.0347 - val_accuracy: 0.5204 - val_loss: 1.7666
# Epoch 67/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0200 - val_accuracy: 0.4796 - val_loss: 1.8986
# Epoch 68/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 0.5000 - val_loss: 1.9578
# Epoch 69/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.5204 - val_loss: 2.0344
# Epoch 70/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.5204 - val_loss: 2.0745
# Epoch 71/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.5204 - val_loss: 2.1142
# Epoch 72/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.5204 - val_loss: 2.1537
# Epoch 73/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.5204 - val_loss: 2.1888
# Epoch 74/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.5204 - val_loss: 2.2195
# Epoch 75/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.5204 - val_loss: 2.2469
# Epoch 76/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.5204 - val_loss: 2.2720
# Epoch 77/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.5204 - val_loss: 2.2955
# Epoch 78/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.5204 - val_loss: 2.3180
# Epoch 79/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.5204 - val_loss: 2.3395
# Epoch 80/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.5204 - val_loss: 2.3601
# Epoch 81/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.5204 - val_loss: 2.3798
# Epoch 82/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.5204 - val_loss: 2.3988
# Epoch 83/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.5204 - val_loss: 2.4169
# Epoch 84/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.5204 - val_loss: 2.4343
# Epoch 85/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.5204 - val_loss: 2.4510
# Epoch 86/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.5204 - val_loss: 2.4671
# Epoch 87/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.5204 - val_loss: 2.4828
# Epoch 88/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.5204 - val_loss: 2.4979
# Epoch 89/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.5204 - val_loss: 2.5125
# Epoch 90/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.5204 - val_loss: 2.5267
# Epoch 91/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.5204 - val_loss: 2.5405
# Epoch 92/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.5204 - val_loss: 2.5539
# Epoch 93/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.5204 - val_loss: 2.5670
# Epoch 94/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.5102 - val_loss: 2.5796
# Epoch 95/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.5102 - val_loss: 2.5920
# Epoch 96/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.5102 - val_loss: 2.6040
# Epoch 97/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.5102 - val_loss: 2.6158
# Epoch 98/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.5102 - val_loss: 2.6273
# Epoch 99/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.5102 - val_loss: 2.6385
# Epoch 100/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.5102 - val_loss: 2.6495
# Epoch 101/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.5102 - val_loss: 2.6602
# Epoch 102/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.5102 - val_loss: 2.6708
# Epoch 103/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.5102 - val_loss: 2.6810
# Epoch 104/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.5102 - val_loss: 2.6913
# Epoch 105/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.5102 - val_loss: 2.7014
# Epoch 106/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.5102 - val_loss: 2.7112
# Epoch 107/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.5102 - val_loss: 2.7210
# Epoch 108/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.5102 - val_loss: 2.7305
# Epoch 109/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.5102 - val_loss: 2.7398
# Epoch 110/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.5102 - val_loss: 2.7489
# Epoch 111/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5102 - val_loss: 2.7579
# Epoch 112/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5102 - val_loss: 2.7668
# Epoch 113/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5102 - val_loss: 2.7755
# Epoch 114/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.5102 - val_loss: 2.7842
# Epoch 115/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.5102 - val_loss: 2.7926
# Epoch 116/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.5102 - val_loss: 2.8009
# Epoch 117/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.5102 - val_loss: 2.8091
# Epoch 118/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.5102 - val_loss: 2.8172
# Epoch 119/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.5102 - val_loss: 2.8251
# Epoch 120/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.5102 - val_loss: 2.8331
# Epoch 121/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.5102 - val_loss: 2.8409
# Epoch 122/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.5102 - val_loss: 2.8487
# Epoch 123/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.5102 - val_loss: 2.8564
# Epoch 124/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.5102 - val_loss: 2.8640
# Epoch 125/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.5102 - val_loss: 2.8715
# Epoch 126/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5102 - val_loss: 2.8789
# Epoch 127/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5102 - val_loss: 2.8863
# Epoch 128/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5102 - val_loss: 2.8935
# Epoch 129/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5102 - val_loss: 2.9006
# Epoch 130/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5102 - val_loss: 2.9076
# Epoch 131/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5102 - val_loss: 2.9146
# Epoch 132/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5102 - val_loss: 2.9215
# Epoch 133/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5102 - val_loss: 2.9284
# Epoch 134/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5102 - val_loss: 2.9351
# Epoch 135/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5102 - val_loss: 2.9419
# Epoch 136/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5102 - val_loss: 2.9485
# Epoch 137/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.5102 - val_loss: 2.9550
# Epoch 138/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.5102 - val_loss: 2.9615
# Epoch 139/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.5102 - val_loss: 2.9679
# Epoch 140/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.5204 - val_loss: 2.9741
# Epoch 141/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 9.8762e-04 - val_accuracy: 0.5204 - val_loss: 2.9803
# Epoch 142/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 9.7362e-04 - val_accuracy: 0.5204 - val_loss: 2.9864
# Epoch 143/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 9.5993e-04 - val_accuracy: 0.5102 - val_loss: 2.9925
# Epoch 144/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 9.4654e-04 - val_accuracy: 0.5102 - val_loss: 2.9986
# Epoch 145/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 9.3344e-04 - val_accuracy: 0.5102 - val_loss: 3.0046
# Epoch 146/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 9.2059e-04 - val_accuracy: 0.5102 - val_loss: 3.0107
# Epoch 147/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 9.0803e-04 - val_accuracy: 0.5102 - val_loss: 3.0166
# Epoch 148/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 8.9580e-04 - val_accuracy: 0.5102 - val_loss: 3.0223
# Epoch 149/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 8.8386e-04 - val_accuracy: 0.5102 - val_loss: 3.0280
# Epoch 150/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 8.7215e-04 - val_accuracy: 0.5102 - val_loss: 3.0335
# Epoch 151/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 8.6068e-04 - val_accuracy: 0.5102 - val_loss: 3.0389
# Epoch 152/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 8.4945e-04 - val_accuracy: 0.5102 - val_loss: 3.0443
# Epoch 153/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 8.3846e-04 - val_accuracy: 0.5102 - val_loss: 3.0496
# Epoch 154/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 8.2771e-04 - val_accuracy: 0.5102 - val_loss: 3.0549
# Epoch 155/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 8.1719e-04 - val_accuracy: 0.5102 - val_loss: 3.0601
# Epoch 156/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 8.0687e-04 - val_accuracy: 0.5102 - val_loss: 3.0653
# Epoch 157/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 7.9676e-04 - val_accuracy: 0.5102 - val_loss: 3.0705
# Epoch 158/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 7.8686e-04 - val_accuracy: 0.5102 - val_loss: 3.0756
# Epoch 159/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 7.7715e-04 - val_accuracy: 0.5102 - val_loss: 3.0806
# Epoch 160/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 7.6763e-04 - val_accuracy: 0.5102 - val_loss: 3.0856
# Epoch 161/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 7.5828e-04 - val_accuracy: 0.5204 - val_loss: 3.0906
# Epoch 162/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 7.4906e-04 - val_accuracy: 0.5102 - val_loss: 3.0955
# Epoch 163/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 7.4002e-04 - val_accuracy: 0.5102 - val_loss: 3.1004
# Epoch 164/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 7.3114e-04 - val_accuracy: 0.5204 - val_loss: 3.1052
# Epoch 165/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 7.2244e-04 - val_accuracy: 0.5204 - val_loss: 3.1101
# Epoch 166/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 7.1390e-04 - val_accuracy: 0.5204 - val_loss: 3.1149
# Epoch 167/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 7.0552e-04 - val_accuracy: 0.5204 - val_loss: 3.1197
# Epoch 168/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 6.9730e-04 - val_accuracy: 0.5204 - val_loss: 3.1245
# Epoch 169/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 6.8924e-04 - val_accuracy: 0.5204 - val_loss: 3.1292
# Epoch 170/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 6.8133e-04 - val_accuracy: 0.5204 - val_loss: 3.1338
# Epoch 171/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 6.7357e-04 - val_accuracy: 0.5204 - val_loss: 3.1384
# Epoch 172/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 6.6595e-04 - val_accuracy: 0.5102 - val_loss: 3.1431
# Epoch 173/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 6.5847e-04 - val_accuracy: 0.5102 - val_loss: 3.1479
# Epoch 174/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 6.5112e-04 - val_accuracy: 0.5204 - val_loss: 3.1526
# Epoch 175/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 6.4385e-04 - val_accuracy: 0.5204 - val_loss: 3.1574
# Epoch 176/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 6.3668e-04 - val_accuracy: 0.5204 - val_loss: 3.1621
# Epoch 177/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 6.2965e-04 - val_accuracy: 0.5306 - val_loss: 3.1670
# Epoch 178/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 6.2274e-04 - val_accuracy: 0.5306 - val_loss: 3.1718
# Epoch 179/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 6.1596e-04 - val_accuracy: 0.5306 - val_loss: 3.1765
# Epoch 180/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 6.0930e-04 - val_accuracy: 0.5306 - val_loss: 3.1814
# Epoch 181/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 6.0274e-04 - val_accuracy: 0.5306 - val_loss: 3.1863
# Epoch 182/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 5.9628e-04 - val_accuracy: 0.5306 - val_loss: 3.1911
# Epoch 183/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 5.8994e-04 - val_accuracy: 0.5306 - val_loss: 3.1958
# Epoch 184/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.8370e-04 - val_accuracy: 0.5306 - val_loss: 3.2006
# Epoch 185/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.7755e-04 - val_accuracy: 0.5306 - val_loss: 3.2052
# Epoch 186/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.7149e-04 - val_accuracy: 0.5306 - val_loss: 3.2097
# Epoch 187/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 5.6555e-04 - val_accuracy: 0.5306 - val_loss: 3.2141
# Epoch 188/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.5972e-04 - val_accuracy: 0.5306 - val_loss: 3.2184
# Epoch 189/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.5399e-04 - val_accuracy: 0.5306 - val_loss: 3.2227
# Epoch 190/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.4835e-04 - val_accuracy: 0.5306 - val_loss: 3.2269
# Epoch 191/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.4278e-04 - val_accuracy: 0.5306 - val_loss: 3.2310
# Epoch 192/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.3731e-04 - val_accuracy: 0.5306 - val_loss: 3.2350
# Epoch 193/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 5.3191e-04 - val_accuracy: 0.5204 - val_loss: 3.2390
# Epoch 194/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.2660e-04 - val_accuracy: 0.5204 - val_loss: 3.2430
# Epoch 195/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.2137e-04 - val_accuracy: 0.5204 - val_loss: 3.2470
# Epoch 196/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.1623e-04 - val_accuracy: 0.5204 - val_loss: 3.2509
# Epoch 197/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 5.1116e-04 - val_accuracy: 0.5204 - val_loss: 3.2548
# Epoch 198/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.0617e-04 - val_accuracy: 0.5204 - val_loss: 3.2587
# Epoch 199/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.0124e-04 - val_accuracy: 0.5204 - val_loss: 3.2626
# Epoch 200/200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 4.9636e-04 - val_accuracy: 0.5204 - val_loss: 3.2664

# %%
thresholds=np.arange(0.0,1.01,0.1)
f1_scores=[]
best_f1=0

#selecting best threshold on val data

y_prob = model.predict([X_emb_val, X_num_val])
for threshold in thresholds:
    y_pred_tr = (y_prob > threshold).astype(int)
    report=classification_report(y_val, y_pred_tr, output_dict=True)
    f1_scores.append(report['macro avg']['f1-score'])

#deciding the best index    
f1_score=max(f1_scores)
index_tr=f1_scores.index(f1_score)
threshold=thresholds[index_tr]

#now deciding F1 on test data with the decided best threshold
y_prob = model.predict([X_emb_test, X_num_test])
y_pred_tr = (y_prob > threshold).astype(int)
report=classification_report(y_test, y_pred_tr, output_dict=True)
f1=report['macro avg']["f1-score"]
print(f"Best Result is f1 {f1} at threshold {threshold}")
results["with Window"]=[f1, threshold, report]
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Best Result is f1 0.6435601198117245 at threshold 0.6000000000000001
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/irtg/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
y_prob = model.predict([X_emb_test, X_num_test])
y_pred = (y_prob > threshold).astype(int)
print(classification_report(y_test, y_pred))

print("confusion_matrix is:")
cm=confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, 
            annot=True, 
            fmt='d', 
            cmap='Blues',
            xticklabels=["Negative", "Positive"],
            yticklabels=["Negative", "Positive"])

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.57      0.60      0.59        20
#            1       0.71      0.69      0.70        29
#
#     accuracy                           0.65        49
#    macro avg       0.64      0.64      0.64        49
# weighted avg       0.66      0.65      0.65        49
#
# confusion_matrix is:

# %%
auc=roc_auc_score(y_test, y_prob)

fpr, tpr, thresholds = roc_curve(y_test, y_prob)

plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # random line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.title("ROC for LSTM with 512 embeddings and 6 numerical features")
plt.show()

# %%
labels = list(results.keys())

f1_scores = [v[0] for v in results.values()]
thresholds = [v[1] for v in results.values()]

bars = plt.bar(labels, f1_scores, color=["steelblue", "orange"])

plt.ylabel("Untuned LSTM F1 Score")
plt.title("F1 Score Comparison")
plt.ylim(0, 1)

# Add F1 + threshold as text
for bar, f1, th in zip(bars, f1_scores, thresholds):
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        f"F1={f1:.3f}\nth={th:.2f}",
        ha="center",
        va="bottom",
        fontsize=10
    )

plt.tight_layout()
plt.show()
